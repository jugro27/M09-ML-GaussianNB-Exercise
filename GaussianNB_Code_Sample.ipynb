# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

data = pd.read_csv('diabetes.csv')

# %%
X = data.copy().drop(columns=['Outcome'])
y = data['Outcome'].copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
X_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   384.000000  384.000000     384.000000     384.000000  384.000000
# mean      3.770833  121.739583      70.554688      20.716146   88.039062
# std       3.383200   32.028788      18.614886      15.785942  123.374723
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000  100.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   47.000000
# 75%       6.000000  142.250000      80.000000      32.250000  140.500000
# max      15.000000  198.000000     122.000000      63.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  384.000000                384.000000  384.000000
# mean    32.144531                  0.465219   33.390625
# std      8.092970                  0.343457   12.005591
# min      0.000000                  0.084000   21.000000
# 25%     27.400000                  0.236750   24.000000
# 50%     32.400000                  0.364000   29.000000
# 75%     36.600000                  0.591500   40.000000
# max     67.100000                  2.420000   81.000000

# %%
X_test.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   384.000000  384.000000      384.00000     384.000000  384.000000
# mean      3.919271  120.049479       67.65625      20.356771   71.559896
# std       3.358671   31.935724       19.98868      16.135371  106.016879
# min       0.000000    0.000000        0.00000       0.000000    0.000000
# 25%       1.000000   99.000000       62.00000       0.000000    0.000000
# 50%       3.000000  115.000000       71.00000      22.000000    0.000000
# 75%       6.000000  139.000000       78.00000      32.000000  115.000000
# max      17.000000  199.000000      114.00000      99.000000  680.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  384.000000                384.000000  384.000000
# mean    31.840625                  0.478534   33.091146
# std      7.677227                  0.319049   11.523368
# min      0.000000                  0.078000   21.000000
# 25%     27.075000                  0.251250   24.000000
# 50%     31.800000                  0.383000   29.000000
# 75%     36.425000                  0.647500   41.000000
# max     57.300000                  1.893000   72.000000

# %%
y_train.describe()
# Out:
# count    384.000000
# mean       0.356771
# std        0.479671
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64

# %%
y_test.describe()
# Out:
# count    384.000000
# mean       0.341146
# std        0.474713
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Outcome, dtype: float64

# %%
gnb = GaussianNB()
y_pred = gnb.fit(X_train, y_train).predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
% (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 384 points : 98

# %%
model = GaussianNB()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
print(model.score(X_train, y_train))
# Out:
# GaussianNB()
#               precision    recall  f1-score   support
#
#            0       0.78      0.86      0.82       253
#            1       0.66      0.53      0.58       131
#
#     accuracy                           0.74       384
#    macro avg       0.72      0.69      0.70       384
# weighted avg       0.74      0.74      0.74       384
#
# [[217  36]
#  [ 62  69]]
# 0.78125
